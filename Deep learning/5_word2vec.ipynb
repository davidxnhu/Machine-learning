# %%
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# D:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# %matplotlib inline

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'term', 'of', 'as', 'originated']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.375685
# Nearest to years: eugenic, batgirl, patron, perseus, freighters, adelaide, reuniting, violins,
# Nearest to which: mannerist, obviously, rollins, excess, minaret, kimberley, isometric, wehrmacht,
# Nearest to for: envy, tonle, neurologists, rod, hemingway, comment, militia, chivalry,
# Nearest to into: leno, kernewek, prussia, addictive, wooden, breast, hummer, agnostic,
# Nearest to these: ken, um, bandmates, benny, polarity, visualizing, duns, writes,
# Nearest to american: incorporeal, surveying, fgc, rabat, polisario, sorted, zapatistas, orgy,
# Nearest to often: boys, caliphs, midday, nathalie, rattle, venturing, abrogated, definitively,
# Nearest to had: biplanes, moivre, lymphocyte, nde, chronic, paleocene, anode, exists,
# Nearest to it: gavin, jaffe, motorised, hydra, ribosome, accessory, viv, administrated,
# Nearest to state: plunder, abiword, revealing, overhauled, sowed, banishing, tricolor, legume,
# Nearest to will: converters, mysore, spiritually, effendi, offenders, fallacious, flynt, muluzi,
# Nearest to also: cartwright, fullest, faltered, martins, bournemouth, brenner, ragga, pancake,
# Nearest to with: hydrogens, comore, odorless, nate, ticketing, capillaries, mais, handoff,
# Nearest to of: hearne, grandmaster, wrongfully, naturalisation, ornithologists, spines, laterally, dheas,
# Nearest to who: crystalline, refuted, spaceman, eschews, babylonia, oracles, schemes, besieged,
# Nearest to seven: harshness, logudorese, exports, shouts, transfiguration, syndicalist, disparities, perched,
# Average loss at step 2000: 4.376988
# Average loss at step 4000: 3.878976
# Average loss at step 6000: 3.800745
# Average loss at step 8000: 3.757942
# Average loss at step 10000: 3.624355
# Nearest to years: patron, eugenic, adelaide, violins, perseus, goss, mutton, satsuki,
# Nearest to which: this, that, it, dangers, also, there, exegetical, mozambique,
# Nearest to for: or, and, keypad, with, in, of, to, jennifer,
# Nearest to into: from, azar, prussia, kernewek, before, compiling, sutcliffe, upon,
# Nearest to these: they, bandmates, ken, duns, flatter, monthly, welland, psionic,
# Nearest to american: incorporeal, ivor, nonlinear, surveying, fgc, lemma, english, sorted,
# Nearest to often: widely, arxiv, filius, itu, there, heller, short, caliphs,
# Nearest to had: has, have, was, chronic, were, navier, is, sought,
# Nearest to it: he, this, there, not, which, they, she, skillful,
# Nearest to state: my, plunder, sparta, cpc, abiword, instantly, uploaded, scrupulously,
# Nearest to will: can, may, would, could, converters, activates, abv, partition,
# Nearest to also: who, that, which, beaconsfield, fullest, pancake, it, precarious,
# Nearest to with: by, and, in, between, for, on, from, to,
# Nearest to of: in, and, midnight, tiryns, for, s, eighteenth, on,
# Nearest to who: he, also, renoir, raven, delight, xry, christoph, crystalline,
# Nearest to seven: five, eight, nine, six, four, three, zero, one,
# Average loss at step 12000: 3.578319
# Average loss at step 14000: 3.613240
# Average loss at step 16000: 3.589176
# Average loss at step 18000: 3.570324
# Average loss at step 20000: 3.548957
# Nearest to years: patron, adelaide, eugenic, perseus, violins, goodyear, mutton, goss,
# Nearest to which: that, this, also, it, what, who, convict, located,
# Nearest to for: keypad, to, in, izmir, with, at, when, classical,
# Nearest to into: from, upon, azar, in, secombe, prussia, arminians, inappropriately,
# Nearest to these: some, they, many, all, several, bech, such, monthly,
# Nearest to american: english, british, incorporeal, ivor, lemma, surveying, fgc, auvergne,
# Nearest to often: widely, sometimes, also, arxiv, there, never, frequently, filius,
# Nearest to had: has, have, was, were, sought, barbour, after, bookstore,
# Nearest to it: he, this, there, she, they, which, skillful, also,
# Nearest to state: my, sparta, instantly, gangs, cpc, candidacy, sowed, fumble,
# Nearest to will: can, would, may, could, should, must, might, converters,
# Nearest to also: which, still, often, now, autoerotic, generally, never, fullest,
# Nearest to with: between, by, in, for, dimensionally, opens, interactively, through,
# Nearest to of: in, and, airframes, alumina, midnight, ultimate, imams, joual,
# Nearest to who: he, they, maoist, and, which, unsound, christoph, already,
# Nearest to seven: five, six, nine, eight, four, three, zero, one,
# Average loss at step 22000: 3.533968
# Average loss at step 24000: 3.439783
# Average loss at step 26000: 3.419275
# Average loss at step 28000: 3.474787
# Average loss at step 30000: 3.410230
# Nearest to years: patron, weeks, days, year, goodyear, eugenic, violins, perseus,
# Nearest to which: that, this, also, there, who, it, these, convict,
# Nearest to for: when, cassandra, jennifer, gbit, consented, utero, spr, if,
# Nearest to into: from, bailiwick, upon, before, in, inappropriately, prussia, arminians,
# Nearest to these: many, some, they, several, all, such, which, both,
# Nearest to american: british, incorporeal, english, brennan, farnese, surveying, deuterocanonical, nonlinear,
# Nearest to often: widely, sometimes, also, generally, usually, frequently, commonly, arxiv,
# Nearest to had: has, have, was, were, having, sought, when, been,
# Nearest to it: he, there, this, she, they, which, always, often,
# Nearest to state: my, governmental, cpc, fumble, disagree, sparta, gangs, tendons,
# Nearest to will: can, would, may, could, should, must, might, cannot,
# Nearest to also: often, which, now, generally, still, never, autoerotic, usually,
# Nearest to with: between, by, endometrium, into, saimei, interactively, barrett, gale,
# Nearest to of: in, although, and, tiryns, husserl, alumina, during, pheromones,
# Nearest to who: he, which, maoist, they, already, and, christoph, amoeboid,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Average loss at step 32000: 3.420099
# Average loss at step 34000: 3.441484
# Average loss at step 36000: 3.361140
# Average loss at step 38000: 3.497011
# Average loss at step 40000: 3.447351
# Nearest to years: days, year, weeks, decades, times, patron, minutes, life,
# Nearest to which: that, this, who, also, it, there, what, exegetical,
# Nearest to for: if, after, in, by, cheney, under, keypad, when,
# Nearest to into: from, through, with, inappropriately, before, arminians, bailiwick, across,
# Nearest to these: some, many, several, such, those, both, all, they,
# Nearest to american: british, ticker, english, deuterocanonical, considerably, incorporeal, french, jumo,
# Nearest to often: sometimes, widely, usually, also, commonly, generally, now, frequently,
# Nearest to had: has, have, were, was, having, saw, been, sought,
# Nearest to it: he, she, they, there, this, which, we, always,
# Nearest to state: fumble, territory, disagree, tracing, sse, governmental, astute, ashkenazim,
# Nearest to will: can, would, may, could, must, should, might, cannot,
# Nearest to also: often, which, now, generally, still, usually, never, hidalgo,
# Nearest to with: between, into, initial, by, through, during, among, when,
# Nearest to of: including, takeshi, for, worldstatesmen, impeccable, in, alumina, abacus,
# Nearest to who: he, which, they, she, maoist, already, xry, still,
# Nearest to seven: eight, six, nine, four, five, zero, three, two,
# Average loss at step 42000: 3.427684
# Average loss at step 44000: 3.279128
# Average loss at step 46000: 3.410959
# Average loss at step 48000: 3.434437
# Average loss at step 50000: 3.436326
# Nearest to years: days, decades, weeks, times, minutes, year, months, mutton,
# Nearest to which: that, this, what, who, also, convict, there, it,
# Nearest to for: after, when, of, during, bistable, in, if, including,
# Nearest to into: from, through, inappropriately, across, upon, secombe, with, errant,
# Nearest to these: many, several, some, those, all, such, both, are,
# Nearest to american: british, italian, ticker, french, deuterocanonical, english, african, auvergne,
# Nearest to often: sometimes, usually, also, commonly, generally, widely, now, frequently,
# Nearest to had: has, have, was, were, been, having, sought, barbour,
# Nearest to it: he, she, there, this, they, which, skillful, callisthenes,
# Nearest to state: government, fumble, governmental, territory, states, gumbo, astute, hutterites,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to also: often, now, generally, still, usually, which, hidalgo, curry,
# Nearest to with: by, between, in, through, into, among, jamo, beggars,
# Nearest to of: in, sutter, for, tiryns, including, impeccable, ultimate, joual,
# Nearest to who: he, she, which, maoist, they, and, already, also,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Average loss at step 52000: 3.458099
# Average loss at step 54000: 3.431054
# Average loss at step 56000: 3.408907
# Average loss at step 58000: 3.284516
# Average loss at step 60000: 3.384681
# Nearest to years: days, decades, weeks, months, times, minutes, year, arcade,
# Nearest to which: that, this, who, what, also, it, these, there,
# Nearest to for: after, against, rearrangement, jeans, viability, without, keypad, aho,
# Nearest to into: from, through, across, secombe, inappropriately, upon, under, against,
# Nearest to these: many, some, several, they, those, all, which, such,
# Nearest to american: british, english, italian, french, ticker, dutch, african, deuterocanonical,
# Nearest to often: usually, sometimes, commonly, generally, widely, also, frequently, now,
# Nearest to had: has, have, was, having, were, barbour, been, sought,
# Nearest to it: he, there, she, this, they, which, we, that,
# Nearest to state: states, government, territory, fumble, governmental, cherries, rowan, fiji,
# Nearest to will: would, can, could, should, must, may, might, cannot,
# Nearest to also: often, which, still, generally, now, who, never, currently,
# Nearest to with: between, among, in, ticketing, through, bidder, against, jamo,
# Nearest to of: including, in, s, sutter, impeccable, pierrot, tiryns, alumina,
# Nearest to who: which, he, she, also, they, already, maoist, there,
# Nearest to seven: eight, five, six, nine, four, three, zero, two,
# Average loss at step 62000: 3.440816
# Average loss at step 64000: 3.362104
# Average loss at step 66000: 3.344781
# Average loss at step 68000: 3.383032
# Average loss at step 70000: 3.376855
# Nearest to years: days, decades, months, year, weeks, times, minutes, centuries,
# Nearest to which: this, that, who, what, also, tombaugh, radiance, these,
# Nearest to for: after, when, against, if, viability, by, mankiewicz, cheney,
# Nearest to into: through, from, across, inappropriately, upon, pets, secombe, subdisciplines,
# Nearest to these: many, several, some, such, those, both, various, they,
# Nearest to american: british, italian, english, french, german, african, indian, ticker,
# Nearest to often: usually, sometimes, commonly, generally, widely, frequently, still, now,
# Nearest to had: has, have, was, having, barbour, were, saw, psr,
# Nearest to it: he, there, she, this, they, itself, still, probably,
# Nearest to state: government, states, territory, city, economies, mengistu, fumble, cmd,
# Nearest to will: would, can, could, should, may, must, might, cannot,
# Nearest to also: often, still, now, which, currently, never, generally, curry,
# Nearest to with: between, against, by, when, among, through, marksmen, while,
# Nearest to of: including, sutter, worldstatesmen, ultimate, rotating, tiryns, s, and,
# Nearest to who: they, which, he, still, she, already, also, maoist,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Average loss at step 72000: 3.401775
# Average loss at step 74000: 3.389261
# Average loss at step 76000: 3.353307
# Average loss at step 78000: 3.234673
# Average loss at step 80000: 3.374383
# Nearest to years: days, months, decades, year, weeks, times, minutes, centuries,
# Nearest to which: this, that, what, also, who, usually, typically, often,
# Nearest to for: if, when, keypad, of, against, to, without, after,
# Nearest to into: through, from, across, upon, inappropriately, secombe, down, cidre,
# Nearest to these: many, some, several, such, those, certain, various, their,
# Nearest to american: british, italian, english, french, german, african, deuterocanonical, irish,
# Nearest to often: usually, sometimes, commonly, generally, frequently, also, typically, now,
# Nearest to had: has, have, having, was, were, barbour, saw, clp,
# Nearest to it: he, there, she, this, they, usually, possible, itself,
# Nearest to state: government, city, national, loaned, guru, states, territory, hutterites,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to also: often, still, now, currently, usually, which, below, sometimes,
# Nearest to with: between, among, in, without, when, while, against, by,
# Nearest to of: in, for, and, actual, including, tiryns, stifle, psychoanalysis,
# Nearest to who: he, she, which, they, never, already, also, still,
# Nearest to seven: five, six, four, nine, eight, three, zero, one,
# Average loss at step 82000: 3.292952
# Average loss at step 84000: 3.349441
# Average loss at step 86000: 3.347210
# Average loss at step 88000: 3.320510
# Average loss at step 90000: 3.242530
# Nearest to years: days, decades, months, year, times, weeks, minutes, centuries,
# Nearest to which: that, this, what, also, who, oy, often, radiance,
# Nearest to for: after, viability, keypad, during, tba, as, at, voiceover,
# Nearest to into: through, across, from, secombe, around, on, inappropriately, grossed,
# Nearest to these: many, several, some, those, such, certain, various, multiple,
# Nearest to american: british, italian, german, english, deuterocanonical, french, and, ide,
# Nearest to often: usually, sometimes, commonly, generally, frequently, typically, still, also,
# Nearest to had: has, have, was, barbour, were, having, since, saw,
# Nearest to it: he, she, there, this, they, itself, often, usually,
# Nearest to state: states, government, guru, city, loaned, sargent, delocalised, national,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to also: often, still, which, now, never, who, actually, standout,
# Nearest to with: between, marksmen, through, by, among, jamo, slapped, in,
# Nearest to of: in, sutter, and, including, ultimate, although, impeccable, tiryns,
# Nearest to who: which, also, he, she, still, maoist, teatro, antikythera,
# Nearest to seven: five, six, eight, four, nine, three, zero, two,
# Average loss at step 92000: 2.736548
# Average loss at step 94000: 3.099679
# Average loss at step 96000: 3.065660
# Average loss at step 98000: 3.221921
# Average loss at step 100000: 3.277177
# Nearest to years: days, months, decades, year, minutes, weeks, times, centuries,
# Nearest to which: that, what, this, who, often, instead, also, both,
# Nearest to for: after, by, without, in, zhuhai, if, bistable, viability,
# Nearest to into: through, across, down, from, inappropriately, out, around, secombe,
# Nearest to these: many, several, some, those, such, various, certain, their,
# Nearest to american: british, english, japanese, australian, israeli, indian, canadian, french,
# Nearest to often: usually, sometimes, commonly, generally, also, frequently, typically, now,
# Nearest to had: has, have, was, having, were, since, barbour, been,
# Nearest to it: he, she, there, this, itself, therefore, they, probably,
# Nearest to state: states, government, loaned, gumbo, guru, city, national, malay,
# Nearest to will: would, could, should, can, must, might, may, cannot,
# Nearest to also: often, still, now, never, actually, commonly, currently, then,
# Nearest to with: by, between, through, in, against, barrett, slapped, pomeroy,
# Nearest to of: tiryns, and, from, ultimate, in, impeccable, for, including,
# Nearest to who: still, which, also, teatro, he, ganglia, often, she,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
